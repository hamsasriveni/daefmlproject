# %% [markdown]
# <a href="https://colab.research.google.com/github/hamsasriveni/daefmlproject/blob/main/studentsexpenses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Dafeml project.csv")
print(df)
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 3      Male    19           3  Hostel          No            No   Motorcycle
# 4    Female    19           2    Home          No            No   Motorcycle
# ..       ...  ...         ...     ...         ...           ...          ...
# 100    Male    19           3  Hostel          No            No   Motorcycle
# 101  Female    19           2    Home          No            No   Motorcycle
# 102    Male    22           3  Hostel          No           Yes          Car
# 103  Female    21           2    Home         Yes            No           No
# 104    Male    22           3  Hostel          No           Yes   Motorcycle
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=105, step=1)

# %%
df.shape
# Out:
# (105, 18)

# %%
df.size
# Out:
# 1890

# %%
df.index
# Out:
# RangeIndex(start=0, stop=105, step=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=105, step=1)

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 105 non-null    object
#  1   Age                    105 non-null    int64
#  2   Study_year             105 non-null    int64
#  3   Living                 105 non-null    object
#  4   Scholarship            105 non-null    object
#  5   Part_time_job          105 non-null    object
#  6   Transporting           105 non-null    object
#  7   Smoking                103 non-null    object
#  8   Drinks                 105 non-null    object
#  9   Games_&_Hobbies        105 non-null    object
#  10  Cosmetics_&_Self-care  105 non-null    object
#  11  Monthly_Subscription   105 non-null    object
#  12  Gym                    105 non-null    object
#  13  stationary             105 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age  Study_year  Monthly_expenses_₹  Unnamed: 16   student id
# count  105.000000  105.000000          105.000000          0.0   105.000000
# mean    20.171429    2.647619         1575.038095          NaN  2623.028571
# std      1.898669    0.999817          920.015655          NaN  1726.425551
# min     17.000000    1.000000          200.000000          NaN  1001.000000
# 25%     19.000000    2.000000          800.000000          NaN  1058.000000
# 50%     19.000000    2.000000         1400.000000          NaN  2014.000000
# 75%     22.000000    4.000000         2000.000000          NaN  5010.000000
# max     25.000000    4.000000         3900.000000          NaN  5098.000000

# %%
df.sample() # display randon row
# Out:
#    Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 37  Male    22           2  Hostel         Yes           Yes          Car
#
#    Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 37      No    Yes             Yes                    No                  Yes
#
#    Gym stationary partys  Monthly_expenses_₹  Unnamed: 16  student id
# 37  No         No     No                 500          NaN        1002

# %%
df.sample(5) # display randon 5 rows
# Out:
#      Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 14  Female    22           4  Hostel         Yes           Yes          Car
# 57    Male    22           4    Home         Yes            No   Motorcycle
# 29  Female    19           2    Home          No            No           No
# 65    Male    19           2    Home          No            No          Car
# 40  Female    22           4  Hostel         Yes           Yes          Yes
#
#    Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 14      No     No              No                   Yes                  Yes
# 57     Yes    Yes             Yes                    No                  Yes
# 29      No     No             Yes                    No                   No
# 65     Yes    Yes             Yes                    No                   No
# 40      No     No              No                   Yes                   No
#
# ...

# %%
df.dtypes
# Out:
# Gender                    object
# Age                        int64
# Study_year                 int64
# Living                    object
# Scholarship               object
# Part_time_job             object
# Transporting              object
# Smoking                   object
# Drinks                    object
# Games_&_Hobbies           object
# Cosmetics_&_Self-care     object
# Monthly_Subscription      object
# Gym                       object
# stationary                object
# partys                    object
# Monthly_expenses_₹         int64
# Unnamed: 16              float64
# student id                 int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')

# %%
df['Age']
# Out:
# 0      21
# 1      25
# 2      23
# 3      19
# 4      19
#        ..
# 100    19
# 101    19
# 102    22
# 103    21
# 104    22
# Name: Age, Length: 105, dtype: int64

# %%
df.nunique()
# Out:
# Gender                    2
# Age                       7
# Study_year                4
# Living                    2
# Scholarship               2
# Part_time_job             2
# Transporting              5
# Smoking                   2
# Drinks                    2
# Games_&_Hobbies           2
# Cosmetics_&_Self-care     2
# Monthly_Subscription      2
# Gym                       3
# stationary                2
# partys                    2
# Monthly_expenses_₹       35
# Unnamed: 16               0
# student id               95
# dtype: int64

# %%
df.count()
# Out:
# Gender                   105
# Age                      105
# Study_year               105
# Living                   105
# Scholarship              105
# Part_time_job            105
# Transporting             105
# Smoking                  103
# Drinks                   105
# Games_&_Hobbies          105
# Cosmetics_&_Self-care    105
# Monthly_Subscription     105
# Gym                      105
# stationary               105
# partys                   105
# Monthly_expenses_₹       105
# Unnamed: 16                0
# student id               105
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# Length: 105, dtype: bool

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Age                     20.171429
# Study_year               2.647619
# Monthly_expenses_₹    1575.038095
# Unnamed: 16                   NaN
# student id            2623.028571
# dtype: float64

# %%
df.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Age                      1.898669
# Study_year               0.999817
# Monthly_expenses_₹     920.015655
# Unnamed: 16                   NaN
# student id            1726.425551
# dtype: float64

# %%
df.min()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Gender                   Female
# Age                           17
# Study_year                     1
# Living                      Home
# Scholarship                   No
# Part_time_job                 No
# Transporting                 Car
# Drinks                        No
# Games_&_Hobbies               No
# Cosmetics_&_Self-care         No
# Monthly_Subscription          No
# Gym                           No
# stationary                    No
# partys                        No
# Monthly_expenses_₹           200
# Unnamed: 16                  NaN
# student id                  1001
# dtype: object

# %%
df.max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Gender                    Male
# Age                          25
# Study_year                    4
# Living                   Hostel
# Scholarship                 Yes
# Part_time_job               Yes
# Transporting                car
# Drinks                      Yes
# Games_&_Hobbies             Yes
# Cosmetics_&_Self-care       Yes
# Monthly_Subscription        Yes
# Gym                         yes
# stationary                  Yes
# partys                      Yes
# Monthly_expenses_₹         3900
# Unnamed: 16                 NaN
# student id                 5098
# dtype: object

# %%
df.nsmallest(2,'Age')
# Out:
#      Gender  Age  Study_year Living Scholarship Part_time_job Transporting  \
# 16  Female    17           1   Home          No            No          Car
# 47  Female    17           1   Home          No            No          Car
#
#    Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 16      No     No              No                    No                   No
# 47      No     No              No                    No                   No
#
#     Gym stationary partys  Monthly_expenses_₹  Unnamed: 16  student id
# 16  Yes        Yes     No                1000          NaN        5069
# 47   No        Yes    Yes                 400          NaN        4038

# %%
df.nlargest(2,'Age')
# Out:
#   Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 1  Male    25           3  Hostel          No           Yes   Motorcycle
# 2  Male    23           2    Home         Yes            No           No
#
#   Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 1      No     No             Yes                   Yes                  Yes
# 2      No     No              No                    No                  Yes
#
#    Gym stationary partys  Monthly_expenses_₹  Unnamed: 16  student id
# 1   No        Yes    Yes                1500          NaN        2035
# 2  Yes        Yes     No                 800          NaN        1013

# %%
df.memory_usage(deep=True)
# Out:
# Index                     128
# Gender                   6616
# Age                       840
# Study_year                840
# Living                   6479
# Scholarship              6222
# Part_time_job            6229
# Transporting             6481
# Smoking                  6171
# Drinks                   6215
# Games_&_Hobbies          6266
# Cosmetics_&_Self-care    6259
# Monthly_Subscription     6247
# Gym                      6249
# stationary               6275
# partys                   6239
# Monthly_expenses_₹        840
# Unnamed: 16               840
# student id                840
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index                    128
# Gender                   840
# Age                      840
# Study_year               840
# Living                   840
# Scholarship              840
# Part_time_job            840
# Transporting             840
# Smoking                  840
# Drinks                   840
# Games_&_Hobbies          840
# Cosmetics_&_Self-care    840
# Monthly_Subscription     840
# Gym                      840
# stationary               840
# partys                   840
# Monthly_expenses_₹       840
# Unnamed: 16              840
# student id               840
# dtype: int64

# %%
df.corr()
# Out:
#                          Age  Study_year  Monthly_expenses_₹  Unnamed: 16  \
# Age                 1.000000    0.751387            0.033778          NaN
# Study_year          0.751387    1.000000            0.061752          NaN
# Monthly_expenses_₹  0.033778    0.061752            1.000000          NaN
# Unnamed: 16              NaN         NaN                 NaN          NaN
# student id          0.278175    0.447327            0.082411          NaN
#
#                     student id
# Age                   0.278175
# Study_year            0.447327
# Monthly_expenses_₹    0.082411
# Unnamed: 16                NaN
# student id            1.000000

# %%
df.count()
# Out:
# Gender                   105
# Age                      105
# Study_year               105
# Living                   105
# Scholarship              105
# Part_time_job            105
# Transporting             105
# Smoking                  103
# Drinks                   105
# Games_&_Hobbies          105
# Cosmetics_&_Self-care    105
# Monthly_Subscription     105
# Gym                      105
# stationary               105
# partys                   105
# Monthly_expenses_₹       105
# Unnamed: 16                0
# student id               105
# dtype: int64

# %%
df.nunique()
# Out:
# Gender                    2
# Age                       7
# Study_year                4
# Living                    2
# Scholarship               2
# Part_time_job             2
# Transporting              5
# Smoking                   2
# Drinks                    2
# Games_&_Hobbies           2
# Cosmetics_&_Self-care     2
# Monthly_Subscription      2
# Gym                       3
# stationary                2
# partys                    2
# Monthly_expenses_₹       35
# Unnamed: 16               0
# student id               95
# dtype: int64

# %%
df['Scholarship'].value_counts()
# Out:
# No     78
# Yes    27
# Name: Scholarship, dtype: int64

# %%
print(df)#Accessing data from dataset
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 3      Male    19           3  Hostel          No            No   Motorcycle
# 4    Female    19           2    Home          No            No   Motorcycle
# ..       ...  ...         ...     ...         ...           ...          ...
# 100    Male    19           3  Hostel          No            No   Motorcycle
# 101  Female    19           2    Home          No            No   Motorcycle
# 102    Male    22           3  Hostel          No           Yes          Car
# 103  Female    21           2    Home         Yes            No           No
# 104    Male    22           3  Hostel          No           Yes   Motorcycle
#
# ...

# %%
df.head() # displays top 5 rows
# Out:
#     Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0  Female    21           2    Home          No            No           No
# 1    Male    25           3  Hostel          No           Yes   Motorcycle
# 2    Male    23           2    Home         Yes            No           No
# 3    Male    19           3  Hostel          No            No   Motorcycle
# 4  Female    19           2    Home          No            No   Motorcycle
#
#   Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 0      No     No              No                   Yes                   No
# 1      No     No             Yes                   Yes                  Yes
# 2      No     No              No                    No                  Yes
# 3      No     No             Yes                   Yes                  Yes
# 4      No     No              No                   Yes                   No
#
# ...

# %%
df.head(10) # displays top 10 rows
# Out:
#     Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0  Female    21           2    Home          No            No           No
# 1    Male    25           3  Hostel          No           Yes   Motorcycle
# 2    Male    23           2    Home         Yes            No           No
# 3    Male    19           3  Hostel          No            No   Motorcycle
# 4  Female    19           2    Home          No            No   Motorcycle
# 5    Male    22           3  Hostel          No           Yes          Car
# 6  Female    21           2    Home         Yes            No           No
# 7    Male    22           3  Hostel          No           Yes   Motorcycle
# 8  Female    18           1    Home         Yes            No           No
# 9    Male    19           1    Home          No            No           No
#
#   Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# ...

# %%
df.tail()# displays bottom 5 rows
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 100    Male    19           3  Hostel          No            No   Motorcycle
# 101  Female    19           2    Home          No            No   Motorcycle
# 102    Male    22           3  Hostel          No           Yes          Car
# 103  Female    21           2    Home         Yes            No           No
# 104    Male    22           3  Hostel          No           Yes   Motorcycle
#
#     Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 100      No     No             Yes                   Yes                  Yes
# 101      No     No              No                   Yes                   No
# 102     Yes    Yes             Yes                    No                   No
# 103      No     No             Yes                    No                  Yes
# 104     Yes     No             Yes                   Yes                  Yes
#
# ...

# %%
df[3:10] # displays rows from 3 to 9 - 10 excluded
# Out:
#     Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 3    Male    19           3  Hostel          No            No   Motorcycle
# 4  Female    19           2    Home          No            No   Motorcycle
# 5    Male    22           3  Hostel          No           Yes          Car
# 6  Female    21           2    Home         Yes            No           No
# 7    Male    22           3  Hostel          No           Yes   Motorcycle
# 8  Female    18           1    Home         Yes            No           No
# 9    Male    19           1    Home          No            No           No
#
#   Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 3      No     No             Yes                   Yes                  Yes
# 4      No     No              No                   Yes                   No
# 5     Yes    Yes             Yes                    No                   No
# ...

# %%
df[['Gender','Age']] # displays specified columns
# Out:
#       Gender  Age
# 0    Female    21
# 1      Male    25
# 2      Male    23
# 3      Male    19
# 4    Female    19
# ..       ...  ...
# 100    Male    19
# 101  Female    19
# 102    Male    22
# 103  Female    21
# 104    Male    22
#
# [105 rows x 2 columns]

# %%
# displays all columns and rows based on location ie based on column and row label
df.loc[:,:]
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 3      Male    19           3  Hostel          No            No   Motorcycle
# 4    Female    19           2    Home          No            No   Motorcycle
# ..       ...  ...         ...     ...         ...           ...          ...
# 100    Male    19           3  Hostel          No            No   Motorcycle
# 101  Female    19           2    Home          No            No   Motorcycle
# 102    Male    22           3  Hostel          No           Yes          Car
# 103  Female    21           2    Home         Yes            No           No
# 104    Male    22           3  Hostel          No           Yes   Motorcycle
#
# ...

# %%
# Series values
df.loc[2:16,:] # displays specified rows( row id 2 to 16 ) and all columns based on location
# Out:
#      Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 2     Male    23           2    Home         Yes            No           No
# 3     Male    19           3  Hostel          No            No   Motorcycle
# 4   Female    19           2    Home          No            No   Motorcycle
# 5     Male    22           3  Hostel          No           Yes          Car
# 6   Female    21           2    Home         Yes            No           No
# 7     Male    22           3  Hostel          No           Yes   Motorcycle
# 8   Female    18           1    Home         Yes            No           No
# 9     Male    19           1    Home          No            No           No
# 10    Male    22           3    Home          No            No          Car
# 11    Male    18           2  Hostel          No            No   Motorcycle
# 12  Female    18           2    Home          No            No           No
# ...

# %%
df.loc[12:100,:] # displays specified rows( row id 12 to 100 )
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 12   Female    18           2    Home          No            No           No
# 13     Male    19           2    Home          No           Yes          Yes
# 14   Female    22           4  Hostel         Yes           Yes          Car
# 15     Male    22           4    Home          No            No          Car
# 16   Female    17           1    Home          No            No          Car
# ..       ...  ...         ...     ...         ...           ...          ...
# 96   Female    19           2  Hostel          No            No          Car
# 97   Female    23           4    Home          No            No           No
# 98   Female    19           3    Home          No            No   Motorcycle
# 99     Male    23           2    Home         Yes            No           No
# 100    Male    19           3  Hostel          No            No   Motorcycle
#
# ...

# %%
df.loc[:,'student id'] # displays all rows( row id 2 to 16 ) and specified column(student id)) b
# Out:
# 0      1012
# 1      2035
# 2      1013
# 3      2014
# 4      1014
#        ...
# 100    2009
# 101    1004
# 102    2008
# 103    1005
# 104    2010
# Name: student id, Length: 105, dtype: int64

# %%
# Series values
df.loc[2:16,['student id','Age']]
# Out:
#     student id  Age
# 2         1013   23
# 3         2014   19
# 4         1014   19
# 5         2012   22
# 6         1056   21
# 7         2059   22
# 8         4026   18
# 9         4036   19
# 10        1113   22
# 11        1059   18
# 12        1078   18
# 13        1076   19
# 14        1085   22
# 15        5089   22
# 16        5069   17

# %%
# Display random rows and Columns if exist
df.loc[[3,12,67,101],['Scholarship','student id','Age']]
# Out:
#     Scholarship  student id  Age
# 3            No        2014   19
# 12           No        1078   18
# 67           No        2010   22
# 101          No        1004   19

# %%
# displays all columns and rows based on position ie integer value of column and row index
df.iloc[:,:]
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 3      Male    19           3  Hostel          No            No   Motorcycle
# 4    Female    19           2    Home          No            No   Motorcycle
# ..       ...  ...         ...     ...         ...           ...          ...
# 100    Male    19           3  Hostel          No            No   Motorcycle
# 101  Female    19           2    Home          No            No   Motorcycle
# 102    Male    22           3  Hostel          No           Yes          Car
# 103  Female    21           2    Home         Yes            No           No
# 104    Male    22           3  Hostel          No           Yes   Motorcycle
#
# ...

# %%
# displays all rows and specified columns 1:4 means 1, 2, and 3
df.iloc[:,1:4]
# Out:
#      Age  Study_year  Living
# 0     21           2    Home
# 1     25           3  Hostel
# 2     23           2    Home
# 3     19           3  Hostel
# 4     19           2    Home
# ..   ...         ...     ...
# 100   19           3  Hostel
# 101   19           2    Home
# 102   22           3  Hostel
# 103   21           2    Home
# 104   22           3  Hostel
#
# [105 rows x 3 columns]

# %%
# displays specified rows and all columns , 3:12 means [3,4,5,6]
# Series values
df.iloc[3:7,:]
# Out:
#     Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 3    Male    19           3  Hostel          No            No   Motorcycle
# 4  Female    19           2    Home          No            No   Motorcycle
# 5    Male    22           3  Hostel          No           Yes          Car
# 6  Female    21           2    Home         Yes            No           No
#
#   Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 3      No     No             Yes                   Yes                  Yes
# 4      No     No              No                   Yes                   No
# 5     Yes    Yes             Yes                    No                   No
# 6      No     No             Yes                    No                  Yes
#
#    Gym stationary partys  Monthly_expenses_₹  Unnamed: 16  student id
# 3   No        Yes    Yes                2000          NaN        2014
# ...

# %%
df.iloc[3:12,1:4]
# Out:
#     Age  Study_year  Living
# 3    19           3  Hostel
# 4    19           2    Home
# 5    22           3  Hostel
# 6    21           2    Home
# 7    22           3  Hostel
# 8    18           1    Home
# 9    19           1    Home
# 10   22           3    Home
# 11   18           2  Hostel

# %%
# displays random specified rows and specified columns
df.iloc[[3,12,67,100],[1,3,5]]
df.iloc[3:12,1:4]
# Out:
#     Age  Study_year  Living
# 3    19           3  Hostel
# 4    19           2    Home
# 5    22           3  Hostel
# 6    21           2    Home
# 7    22           3  Hostel
# 8    18           1    Home
# 9    19           1    Home
# 10   22           3    Home
# 11   18           2  Hostel

# %%
df[df['Age']>20] # displays all the records whose age >20
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 5      Male    22           3  Hostel          No           Yes          Car
# 6    Female    21           2    Home         Yes            No           No
# 7      Male    22           3  Hostel          No           Yes   Motorcycle
# 10     Male    22           3    Home          No            No          Car
# 14   Female    22           4  Hostel         Yes           Yes          Car
# 15     Male    22           4    Home          No            No          Car
# 18   Female    23           4    Home          No            No           No
# 21   Female    22           4    Home         Yes           Yes          Car
# ...

# %%
df[df['Age']>20].head(8) # displays the records whose age >20 (top 8)
# Out:
#      Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0   Female    21           2    Home          No            No           No
# 1     Male    25           3  Hostel          No           Yes   Motorcycle
# 2     Male    23           2    Home         Yes            No           No
# 5     Male    22           3  Hostel          No           Yes          Car
# 6   Female    21           2    Home         Yes            No           No
# 7     Male    22           3  Hostel          No           Yes   Motorcycle
# 10    Male    22           3    Home          No            No          Car
# 14  Female    22           4  Hostel         Yes           Yes          Car
#
#    Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 0       No     No              No                   Yes                   No
# 1       No     No             Yes                   Yes                  Yes
# ...

# %%
df[df['Age']>20].loc[2:5] # displays the few records (2 to 5 ) whose age >30
# Out:
#   Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 2  Male    23           2    Home         Yes            No           No
# 5  Male    22           3  Hostel          No           Yes          Car
#
#   Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 2      No     No              No                    No                  Yes
# 5     Yes    Yes             Yes                    No                   No
#
#    Gym stationary partys  Monthly_expenses_₹  Unnamed: 16  student id
# 2  Yes        Yes     No                 800          NaN        1013
# 5  Yes        Yes     No                3000          NaN        2012

# %%
df[df['Age']>20].loc[2:5,['Age','student id']]
# Out:
#    Age  student id
# 2   23        1013
# 5   22        2012

# %%
df[df['Age']>20].iloc[2:5,3:4]
# Out:
#    Living
# 2    Home
# 5  Hostel
# 6    Home

# %%
df[df['Age']>20] # displays all rows whose age >20
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 5      Male    22           3  Hostel          No           Yes          Car
# 6    Female    21           2    Home         Yes            No           No
# 7      Male    22           3  Hostel          No           Yes   Motorcycle
# 10     Male    22           3    Home          No            No          Car
# 14   Female    22           4  Hostel         Yes           Yes          Car
# 15     Male    22           4    Home          No            No          Car
# 18   Female    23           4    Home          No            No           No
# 21   Female    22           4    Home         Yes           Yes          Car
# ...

# %%
df.loc[df['Age']==22.0,['student id','Age']]
# Out:
#      student id  Age
# 5          2012   22
# 7          2059   22
# 10         1113   22
# 14         1085   22
# 15         5089   22
# 21         1045   22
# 23         5059   22
# 26         1013   22
# 30         2046   22
# 35         5060   22
# 37         1002   22
# 40         5077   22
# 41         2072   22
# 45         5048   22
# 46         5098   22
# 52         5017   22
# 54         5021   22
# 57         5001   22
# 61         5011   22
# 63         5044   22
# 66         5061   22
# 67         2010   22
# 71         5023   22
# 72         5003   22
# 80         2042   22
# 82         2021   22
# 85         2052   22
# 89         5077   22
# 93         5032   22
# 94         5035   22
# 102        2008   22
# 104        2010   22

# %%
df.loc[(df['Age']>20)&(df['Gender']=='Male'),['student id','Age','Gender']]
# Out:
# Empty DataFrame
# Columns: [student id, Age, Gender]
# Index: []

# %%
# demonstrates isin () - check the existence of value in a given list
ag=[22.0,35.0]
df.loc[df['Age'].isin(ag),['student id','Age']]
# Out:
#      student id  Age
# 5          2012   22
# 7          2059   22
# 10         1113   22
# 14         1085   22
# 15         5089   22
# 21         1045   22
# 23         5059   22
# 26         1013   22
# 30         2046   22
# 35         5060   22
# 37         1002   22
# 40         5077   22
# 41         2072   22
# 45         5048   22
# 46         5098   22
# 52         5017   22
# 54         5021   22
# 57         5001   22
# 61         5011   22
# 63         5044   22
# 66         5061   22
# 67         2010   22
# 71         5023   22
# 72         5003   22
# 80         2042   22
# 82         2021   22
# 85         2052   22
# 89         5077   22
# 93         5032   22
# 94         5035   22
# 102        2008   22
# 104        2010   22

# %%
df.Age.value_counts()
# Out:
# 19    33
# 22    32
# 18    19
# 21     8
# 23     8
# 17     4
# 25     1
# Name: Age, dtype: int64

# %%
df[(df.Age>=22) & (df.Scholarship==1)]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Study_year, Living, Scholarship, Part_time_job, Transporting, Smoking, Drinks, Games_&_Hobbies, Cosmetics_&_Self-care, Monthly_Subscription, Gym, stationary, partys, Monthly_expenses_₹, Unnamed: 16, student id]
# Index: []

# %%
# Rename the column - method 1
print(df.columns)
dt=df.rename(columns={'Gender':'Sex'}) # Sex renamed to sex
print("\n\nModified columns \n\n",dt.columns)
# Out:
# Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')
#
#
# Modified columns
#
#  Index(['Sex', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')

# %%
# other way to rename the column -method 2
print(df.columns)
dt=df.rename({'Transporting':'Transportation'},axis=1) # transporting renamed to transportation
print("\n\nModified columns \n\n",dt.columns)
# Out:
# Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')
#
#
# Modified columns
#
#  Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transportation', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')

# %%
# Dropping the column - Parch - method 1
print(df.columns)
dss=df.drop(columns=['student id'])
# Out:
# Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')

# %%
dss.columns
# Out:
# Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16'],
#       dtype='object')

# %%
# Dropping the column - Stationary - method 2
print(df.columns)
ds=df.drop('stationary',axis=1)
ds.columns
# Out:
# Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')
# Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'partys',
#        'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')

# %%
# Dropping the multiple columns
print(df.columns)
ds=df.drop(columns=['Study_year','Part_time_job'])
ds.columns
# Out:
# Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')
# Index(['Gender', 'Age', 'Living', 'Scholarship', 'Transporting', 'Smoking',
#        'Drinks', 'Games_&_Hobbies', 'Cosmetics_&_Self-care',
#        'Monthly_Subscription', 'Gym', 'stationary', 'partys',
#        'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')

# %%
df
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 3      Male    19           3  Hostel          No            No   Motorcycle
# 4    Female    19           2    Home          No            No   Motorcycle
# ..       ...  ...         ...     ...         ...           ...          ...
# 100    Male    19           3  Hostel          No            No   Motorcycle
# 101  Female    19           2    Home          No            No   Motorcycle
# 102    Male    22           3  Hostel          No           Yes          Car
# 103  Female    21           2    Home         Yes            No           No
# 104    Male    22           3  Hostel          No           Yes   Motorcycle
#
# ...

# %%
df=pd.read_csv("/content/Dafeml project.csv")#Check for missing values
print(df)
print(df.shape)
print(df.ndim)
print(df.count())
print("\n\n",df.nunique())
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 3      Male    19           3  Hostel          No            No   Motorcycle
# 4    Female    19           2    Home          No            No   Motorcycle
# ..       ...  ...         ...     ...         ...           ...          ...
# 100    Male    19           3  Hostel          No            No   Motorcycle
# 101  Female    19           2    Home          No            No   Motorcycle
# 102    Male    22           3  Hostel          No           Yes          Car
# 103  Female    21           2    Home         Yes            No           No
# 104    Male    22           3  Hostel          No           Yes   Motorcycle
#
# ...

# %%
#Display all columns
df.columns
# Out:
# Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16', 'student id'],
#       dtype='object')

# %%
#check for nan value - if exists returns true ,else false
df.isna()
#df.isnull # isnull is alias of isna
# Out:
#      Gender    Age  Study_year  Living  Scholarship  Part_time_job  \
# 0     False  False       False   False        False          False
# 1     False  False       False   False        False          False
# 2     False  False       False   False        False          False
# 3     False  False       False   False        False          False
# 4     False  False       False   False        False          False
# ..      ...    ...         ...     ...          ...            ...
# 100   False  False       False   False        False          False
# 101   False  False       False   False        False          False
# 102   False  False       False   False        False          False
# 103   False  False       False   False        False          False
# 104   False  False       False   False        False          False
#
#      Transporting  Smoking  Drinks  Games_&_Hobbies  Cosmetics_&_Self-care  \
# 0           False    False   False            False                  False
# ...

# %%
#Return summation of null value -columwise
df.isna().sum()
# Out:
# Gender                     0
# Age                        0
# Study_year                 0
# Living                     0
# Scholarship                0
# Part_time_job              0
# Transporting               0
# Smoking                    2
# Drinks                     0
# Games_&_Hobbies            0
# Cosmetics_&_Self-care      0
# Monthly_Subscription       0
# Gym                        0
# stationary                 0
# partys                     0
# Monthly_expenses_₹         0
# Unnamed: 16              105
# student id                 0
# dtype: int64

# %%
#Return true if all values in a column is null
df.isna().all()
# Out:
# Gender                   False
# Age                      False
# Study_year               False
# Living                   False
# Scholarship              False
# Part_time_job            False
# Transporting             False
# Smoking                  False
# Drinks                   False
# Games_&_Hobbies          False
# Cosmetics_&_Self-care    False
# Monthly_Subscription     False
# Gym                      False
# stationary               False
# partys                   False
# Monthly_expenses_₹       False
# Unnamed: 16               True
# student id               False
# dtype: bool

# %%
#Return true if any null value exist in column
df.isna().any()
# Out:
# Gender                   False
# Age                      False
# Study_year               False
# Living                   False
# Scholarship              False
# Part_time_job            False
# Transporting             False
# Smoking                   True
# Drinks                   False
# Games_&_Hobbies          False
# Cosmetics_&_Self-care    False
# Monthly_Subscription     False
# Gym                      False
# stationary               False
# partys                   False
# Monthly_expenses_₹       False
# Unnamed: 16               True
# student id               False
# dtype: bool

# %%
#Return columns which contain null value
df.columns[df.isna().any()]
# Out:
# Index(['Smoking', 'Unnamed: 16'], dtype='object')

# %%
#Return the all records of columns which contain atleast null value in column
df[df.columns[df.isna().any()]]
# Out:
#     Smoking  Unnamed: 16
# 0        No          NaN
# 1        No          NaN
# 2        No          NaN
# 3        No          NaN
# 4        No          NaN
# ..      ...          ...
# 100      No          NaN
# 101      No          NaN
# 102     Yes          NaN
# 103      No          NaN
# 104     Yes          NaN
#
# [105 rows x 2 columns]

# %%
df.shape
# Out:
# (105, 18)

# %%
# Drop the row which contain atleast one null value - method 1
print(df.shape)
ds=df.dropna()
ds.shape
# Out:
# (105, 18)
# (0, 18)

# %%
# Drop the row which contain atleast one null value - method 2
print(df.shape)
ds=df.dropna(axis=0)
ds.shape
# Out:
# (105, 18)
# (0, 18)

# %%
# Drop the column which contain atleast one null value
print(df.shape)
dd=df.dropna(axis=1)
dd.shape
# Out:
# (105, 18)
# (105, 16)

# %%
# Fill the null values with a string notdefined
print(df)
dc=df.fillna('notdefined')
dc
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 3      Male    19           3  Hostel          No            No   Motorcycle
# 4    Female    19           2    Home          No            No   Motorcycle
# ..       ...  ...         ...     ...         ...           ...          ...
# 100    Male    19           3  Hostel          No            No   Motorcycle
# 101  Female    19           2    Home          No            No   Motorcycle
# 102    Male    22           3  Hostel          No           Yes          Car
# 103  Female    21           2    Home         Yes            No           No
# 104    Male    22           3  Hostel          No           Yes   Motorcycle
#
# ...

# %%
# Fill the null values with a zero - 0
dn=df.fillna(0)
dn
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 3      Male    19           3  Hostel          No            No   Motorcycle
# 4    Female    19           2    Home          No            No   Motorcycle
# ..       ...  ...         ...     ...         ...           ...          ...
# 100    Male    19           3  Hostel          No            No   Motorcycle
# 101  Female    19           2    Home          No            No   Motorcycle
# 102    Male    22           3  Hostel          No           Yes          Car
# 103  Female    21           2    Home         Yes            No           No
# 104    Male    22           3  Hostel          No           Yes   Motorcycle
#
# ...

# %%
# display the columns which contain null value
df.columns[df.isna().any()]
# Out:
# Index(['Smoking', 'Unnamed: 16'], dtype='object')

# %%
# drops the rows which contain null value in a column Age
print(df.isna().sum())
dx=df.dropna(subset=['Age'])
print(dx.isna().sum())
# Out:
# Gender                     0
# Age                        0
# Study_year                 0
# Living                     0
# Scholarship                0
# Part_time_job              0
# Transporting               0
# Smoking                    2
# Drinks                     0
# Games_&_Hobbies            0
# Cosmetics_&_Self-care      0
# Monthly_Subscription       0
# Gym                        0
# stationary                 0
# partys                     0
# Monthly_expenses_₹         0
# Unnamed: 16              105
# student id                 0
# dtype: int64
# Gender                     0
# Age                        0
# Study_year                 0
# Living                     0
# Scholarship                0
# Part_time_job              0
# Transporting               0
# Smoking                    2
# Drinks                     0
# Games_&_Hobbies            0
# Cosmetics_&_Self-care      0
# Monthly_Subscription       0
# Gym                        0
# ...

# %%
# decrease age by 1 year
df['Age']
def Dob(x):
 return (2021-x)
df['DOBUpdated']=df['Age'].apply(Dob)
df
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0    Female    21           2    Home          No            No           No
# 1      Male    25           3  Hostel          No           Yes   Motorcycle
# 2      Male    23           2    Home         Yes            No           No
# 3      Male    19           3  Hostel          No            No   Motorcycle
# 4    Female    19           2    Home          No            No   Motorcycle
# ..       ...  ...         ...     ...         ...           ...          ...
# 100    Male    19           3  Hostel          No            No   Motorcycle
# 101  Female    19           2    Home          No            No   Motorcycle
# 102    Male    22           3  Hostel          No           Yes          Car
# 103  Female    21           2    Home         Yes            No           No
# 104    Male    22           3  Hostel          No           Yes   Motorcycle
#
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Study_year', 'Living', 'Scholarship', 'Part_time_job',
#        'Transporting', 'Smoking', 'Drinks', 'Games_&_Hobbies',
#        'Cosmetics_&_Self-care', 'Monthly_Subscription', 'Gym', 'stationary',
#        'partys', 'Monthly_expenses_₹', 'Unnamed: 16', 'student id',
#        'DOBUpdated'],
#       dtype='object')
